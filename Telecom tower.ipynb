# %%
# !pip install ultralytics
from IPython import display
display.clear_output()
from IPython.display import Image
import os
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.176 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=train epochs=25 data="/content/drive/MyDrive/Road_hole/roadholes.v1i.yolov8/data.yaml" model=yolov8m.pt
# Out:
# Ultralytics YOLOv8.0.176 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
pip install torch opencv-python

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt source="/content/drive/MyDrive/Road_hole/roadholes.v1i.yolov8/2.mp4" show=True  name=yolov8m.pt
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.176 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients
#
# video 1/1 (1/888) /content/drive/MyDrive/Road_hole/roadholes.v1i.yolov8/2.mp4: 384x640 24 potholes, 203.3ms
# video 1/1 (2/888) /content/drive/MyDrive/Road_hole/roadholes.v1i.yolov8/2.mp4: 384x640 20 potholes, 25.8ms
# video 1/1 (3/888) /content/drive/MyDrive/Road_hole/roadholes.v1i.yolov8/2.mp4: 384x640 20 potholes, 25.8ms
# video 1/1 (4/888) /content/drive/MyDrive/Road_hole/roadholes.v1i.yolov8/2.mp4: 384x640 21 potholes, 25.8ms
# video 1/1 (5/888) /content/drive/MyDrive/Road_hole/roadholes.v1i.yolov8/2.mp4: 384x640 22 potholes, 24.6ms
# video 1/1 (6/888) /content/drive/MyDrive/Road_hole/roadholes.v1i.yolov8/2.mp4: 384x640 27 potholes, 22.7ms
# ...

# %%
_
